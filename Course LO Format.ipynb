# %%
import pandas as pd
from collections import Counter
from tqdm import tqdm

# %%
gg = pd.read_csv('C:/Users/sanat/Downloads/V2LBT_lo.csv')

# %%
lo_formatted = []
for i in gg.lo_formatted:
    if type(i) == str:
        lo_formatted.append(i.replace('&nbsp; ',"").replace('&nbsp;',''))
    else:
        lo_formatted.append(i)

# %%
gg.lo_formatted = lo_formatted

# %%
gg.to_csv('C:/Users/sanat/Downloads/V2LBT_lo_v1.csv', index=False)

# %% [markdown]
# ## Course Master Manipulation

# %%
df = pd.read_csv('C:/Users/sanat/Downloads/CM_lo.csv')

# %%
lo_formatted = [str(i).replace('\r', "").replace("<b>", "")
                .replace("<u>", "").replace("</u>", "")
                .replace("</b>","").replace("<br>", " ")
                .replace("<p>","").replace("</p>","")
                .replace("&nbsp; ", "").replace("&nbsp;", "")
                .replace("<div>","").replace("</div>","")
                .replace("<span>","").replace("</span>","") for i in df.lo_unformatted]

# %%
df['lo_formatted'] = lo_formatted

# %%
df
# Out:
#            course                                           activity  \
# 0        V2L-ADCS           ALM 4.2.4-2                         DBST
# 1        V2L-ADCS          ALM 2.3.3-2                          DBST
# 2        V2L-ADCS      ALM 2.3.3-1                              DBST
# 3        V2L-ADCS         ALM 2.2.4-1                           DBST
# 4        V2L-ADCS               ALM 1.4.5-2                     DBST
# ...           ...                                                ...
# 12945  V2L-Thermo  ALM 5.1.2-3                                   ...
# 12946  V2L-Thermo  ALM 5.1.1-4                                   ...
# 12947  V2L-Thermo    ALM 5.1.1-1                                DBST
# 12948  V2L-Thermo  ALM 6.1.1-2                                   ...
# 12949  V2L-Thermo  ALM 2.1.3-2                                   ...
#
#                                           lo_unformatted  \
# 0      <b><u>Active Learning Outcomes: 32 min duratio...
# 1      <b><u>Active Learning Outcomes: 6 min duration...
# 2      <b><u>Active Learning Outcomes: 6 min duration...
# 3      <b><u>Active Learning Outcomes: 21 min duratio...
# 4      <b><u>Active Learning Outcomes: 15 min duratio...
# ...                                                  ...
# 12945  <b><u>Active Learning Outcomes: 23 min duratio...
# 12946  <b><u>Active Learning Outcomes: 13 min duratio...
# 12947  <b><u>Active Learning Outcomes: 23 min duratio...
# 12948  <b><u>Active Learning Outcomes: 20 min duratio...
# 12949  <b><u>Active Learning Outcomes: 39 min duratio...
#
#                                             lo_formatted
# 0      Active Learning Outcomes: 32 min duration. ALO...
# 1      Active Learning Outcomes: 6 min duration. ALO ...
# 2      Active Learning Outcomes: 6 min duration. ALO ...
# 3      Active Learning Outcomes: 21 min duration. ALO...
# 4      Active Learning Outcomes: 15 min duration. ALO...
# ...                                                  ...
# 12945  Active Learning Outcomes: 23 min duration. ALO...
# 12946  Active Learning Outcomes: 13 min duration. ALO...
# 12947  Active Learning Outcomes: 23 min duration. ALO...
# 12948  Active Learning Outcomes: 20 min duration. ALO...
# 12949  Active Learning Outcomes: 39 min duration. ALO...
#
# [12950 rows x 4 columns]

# %%
Counter([i.split()[0] for i in df.activity])
# Out:
# Counter({'ALM': 6421,
#          'VLM': 2693,
#          'PSM': 2784,
#          'GPSM': 462,
#          'ALO': 11,
#          'VLM-': 2,
#          'LM': 516,
#          'PLM': 1,
#          'ALM-5.2.2-3': 1,
#          'ALM-5.1.2-3': 1,
#          'ALM-4.1.1-2': 1,
#          'ALM-5.2.1-3': 2,
#          'ALM4.3.1-3': 1,
#          'ALM1.1.2-1': 1,
#          'ALM11.3.2-3': 1,
#          'ALM3.2.1-3': 1,
#          'ALM2.2.2-1': 1,
#          'ALM4.3.2-3': 1,
#          'ALM4.3.1-1': 1,
#          'ALM4.2.2-3': 1,
#          'ALM5.3.1-5': 1,
#          'ALM-7.1.1-2': 1,
#          'ALM-2.3.1-2': 1,
#          'ALM-2.3.1-1': 1,
#          'ALM1.2.4-1&2&3': 1,
#          'ALM1.2.4-4': 1,
#          'ALM15.3.2-2': 1,
#          'ALM15.3.2-1': 1,
#          'ALM24.2.1-5': 1,
#          'VLM30.1.5B': 1,
#          'ALM4.2.2-5': 1,
#          'ALM15.4.1-1': 1,
#          'ALM8.2.2-2': 1,
#          'ALM6.1.3-2': 1,
#          'ALM2.1.2-2': 1,
#          'ALM2.1.2-1': 1,
#          'ALM1.2.2-1': 1,
#          'ALM2.2.1-2': 1,
#          'ALM1.1.2-2': 1,
#          'ALM-3.3.1-3': 1,
#          'ALM-5.2.1-5': 1,
#          'ALM-5.2.1-4': 1,
#          'ALM-5.2.1-2': 1,
#          'ALM-5.2.1-1': 1,
#          'ALM-8.1.2-4': 1,
#          'ALM-8.1.2-3': 1,
#          'ALM-8.1.2-2': 1,
#          'ALM-8.1.2-1': 1,
#          'ALM-8.2.2-2': 1,
#          'ALM-8.2.2-1': 1,
#          'ALM-8.1.1-4': 1,
#          'ALM-8.1.1-2': 1,
#          'ALM-8.1.1-1': 1,
#          'ALM-2.4.2-2': 1,
#          'ALM-2.4.2-1': 1,
#          'ALM-3.3.1-1': 1,
#          'ALM-3.3.1-2': 1,
#          'ALM-1.2.2-1': 1,
#          'ALM-2.2.2-1': 1,
#          'ALM-8.3.2-2': 1,
#          'ALM-12.1.4-1': 1,
#          'ALM-12.1.4-3': 1,
#          'ALM-2.2.3-2': 1,
#          'ALM-8.2.5-5': 1,
#          'ALM-2.2.3-3': 1,
#          'ALM4.3.3-2': 1,
#          'PSM14.1.2': 1})

# %%
indices = [idx for idx, val in enumerate(df.activity) if (val.startswith("ALM") or val.startswith("PSM") or val.startswith("GPSM"))]

# %%
len(indices)
# Out:
# 9726

# %%
import re
def generate_display_fields(df):
    standardized_set = []
    for idx, i in enumerate(df.activity):
        shortened_str = re.sub("[^0-9,.-]", "", i)
        sst = shortened_str.split(".")
        if len(sst) == 2:
            standardized = 'U' + sst[0] + 'S' + sst[1]
        else:
            standardized = "U" + sst[0] + "S" + sst[1] + "T" + "".join(sst[2:])
        
        if standardized[:2] == 'U-':
            standardized = "U" + standardized[2:]
        
        standardized_set.append(standardized)
    return standardized_set

def generate_activity_type(df):
    activity_set = []
    option_set = ['ALM', 'GPSM', 'PSM', None]
    for idx, i in enumerate(df.activity):
        c = -1
        if option_set[0] in i:
            c = 0
        elif option_set[1] in i:
            c = 1
        elif option_set[2] in i:
            c = 2
        else:
            c = 3
        activity_set.append(option_set[c])
    return activity_set

def generate_duration_cols(df):
    dur_removed, dur = [], []
    word, length = 'duration', 10
    for i in df.lo_formatted:
        if word in i:
            ind = i.index(word)
            dur_removed.append(i[ind + length:])
            sst = i[:ind].split()
            c = 0
            for j in sst:
                if j.isnumeric():
                    c = 1
                    dur.append(j)        
            if not c:
                dur.append(0)
        else:
            dur_removed.append(i)
            dur.append(0)
    return dur_removed, dur
        
def generate_ust_cols(df):
    s_set = []
    for i in list(df['activity_formatted']):
        q = tuple([c for c in re.split(r'(\d+)', i) if c.isdigit()])
        s_set.append(q)
    return s_set

# %%
display_view = generate_display_fields(df)
df['activity_formatted'] = display_view

df['sorting_col'] = generate_ust_cols(df)

act_type = generate_activity_type(df)
df['activity_type'] = act_type

dur_removed, dur = generate_duration_cols(df)
df['lo_formatted_duration_removed'] = dur_removed
df['duration'] = dur

# %%
output_folder = "los_course_output/"
import numpy as np
def generate_course_files(df, out_path):
    courses = set(df['course'])
    for course in tqdm(courses):
        sub_df = df[df.course == course]
        try:
            sorted_sub_df = sub_df.sort_values(by='sorting_col')
            ss_df_copy = sorted_sub_df.copy()
            ss_df_copy = ss_df_copy.drop(columns=['sorting_col'])
            print(f"Outputting csv for course {course}")
            csv_path = out_path + course + ".csv"
            ss_df_copy.to_csv(csv_path, index=False)
        except:
            print(f"ERROR for course {course}")
            
subset_df = df.iloc[indices] # Create subset dataframe        
generate_course_files(subset_df, output_folder)
# Out:
#  26%|█████████████████████▍                                                             | 8/31 [00:00<00:00, 76.22it/s]
# Outputting csv for course V2L-FM
# Outputting csv for course V2L-CS
# Outputting csv for course V2L-EM
# Outputting csv for course V2L-EDC
# Outputting csv for course V2L-DiscMath
# Outputting csv for course V2L-TOM
# Outputting csv for course V2L-EMechanics
# Outputting csv for course V2L-M2
# Outputting csv for course V2L-AnaCirc
# Outputting csv for course V2L-DigiElx
# Outputting csv for course V2L-BEE
# Outputting csv for course V2L-Survy
# Outputting csv for course V2L-Thermo
# Outputting csv for course V2L-EMMI
# Outputting csv for course V2L-SOM
# Outputting csv for course V2L-RCC
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:00<00:00, 88.88it/s]
# Outputting csv for course V2L-M1
# Outputting csv for course V2L-FOCP
# Outputting csv for course V2L-DBMS
# Outputting csv for course V2L-BMC
# Outputting csv for course V2L-M3
# Outputting csv for course V2L-NM
# Outputting csv for course V2L-ADCS
# Outputting csv for course V2L-NAS
# Outputting csv for course V2L-Soil
# Outputting csv for course V2L-SAS
# Outputting csv for course V2L-HMT
# Outputting csv for course V2L-ProdEng
# Outputting csv for course V2L-DS
# Outputting csv for course V2L-TOC
# Outputting csv for course V2L-OS

# %%
subset_df
# Out:
#            course                                           activity  \
# 0        V2L-ADCS           ALM 4.2.4-2                         DBST
# 1        V2L-ADCS          ALM 2.3.3-2                          DBST
# 2        V2L-ADCS      ALM 2.3.3-1                              DBST
# 3        V2L-ADCS         ALM 2.2.4-1                           DBST
# 4        V2L-ADCS               ALM 1.4.5-2                     DBST
# ...           ...                                                ...
# 12945  V2L-Thermo  ALM 5.1.2-3                                   ...
# 12946  V2L-Thermo  ALM 5.1.1-4                                   ...
# 12947  V2L-Thermo    ALM 5.1.1-1                                DBST
# 12948  V2L-Thermo  ALM 6.1.1-2                                   ...
# 12949  V2L-Thermo  ALM 2.1.3-2                                   ...
#
#                                           lo_unformatted  \
# 0      <b><u>Active Learning Outcomes: 32 min duratio...
# 1      <b><u>Active Learning Outcomes: 6 min duration...
# 2      <b><u>Active Learning Outcomes: 6 min duration...
# 3      <b><u>Active Learning Outcomes: 21 min duratio...
# 4      <b><u>Active Learning Outcomes: 15 min duratio...
# ...                                                  ...
# 12945  <b><u>Active Learning Outcomes: 23 min duratio...
# 12946  <b><u>Active Learning Outcomes: 13 min duratio...
# 12947  <b><u>Active Learning Outcomes: 23 min duratio...
# 12948  <b><u>Active Learning Outcomes: 20 min duratio...
# 12949  <b><u>Active Learning Outcomes: 39 min duratio...
#
#                                             lo_formatted activity_formatted  \
# 0      Active Learning Outcomes: 32 min duration. ALO...           U4S2T4-2
# 1      Active Learning Outcomes: 6 min duration. ALO ...           U2S3T3-2
# 2      Active Learning Outcomes: 6 min duration. ALO ...           U2S3T3-1
# 3      Active Learning Outcomes: 21 min duration. ALO...           U2S2T4-1
# 4      Active Learning Outcomes: 15 min duration. ALO...           U1S4T5-2
# ...                                                  ...                ...
# 12945  Active Learning Outcomes: 23 min duration. ALO...           U5S1T2-3
# 12946  Active Learning Outcomes: 13 min duration. ALO...           U5S1T1-4
# 12947  Active Learning Outcomes: 23 min duration. ALO...           U5S1T1-1
# 12948  Active Learning Outcomes: 20 min duration. ALO...           U6S1T1-2
# 12949  Active Learning Outcomes: 39 min duration. ALO...           U2S1T3-2
#
#                            lo_formatted_duration_removed duration
# 0      ALO 4.2.4-2: Recall SNR at the Output of the F...       32
# 1      ALO 2.3.3-2: Show the Phasor Representation of...        6
# 2      ALO 2.3.3-1: Show the Phasor Representation of...        6
# 3      ALO 2.2.4-1: Describe Demodulation of FM Signa...       21
# 4                ALO 1.4.5-2: Compare various AM Systems       15
# ...                                                  ...      ...
# 12945  ALO 5.1.2-3: Recall the concept of Triple Poin...       23
# 12946  ALO 5.1.1-4: Derive the expression for various...       13
# 12947  ALO 5.1.1-1: Recall the concept of Phase chang...       23
# 12948  ALO 6.1.1-2: Recall the following Laws:\n i. D...       20
# 12949  ALO 2.1.3-2: Derive the Steady Flow Energy Equ...       39
#
# [9726 rows x 7 columns]

# %%
gg = [i.split('-')[0] for i in list(subset_df['activity_formatted'])]
qq = list(subset_df['activity_formatted'])

# %%
k =subset_df[subset_df.course=='V2L-M2']

# %%
k.sort_values(by='activity_formatted')
# Out:
#       course    activity                                     lo_unformatted  \
# 7922  V2L-M2  PSM 10.1.1  <p></p><div><u>Learning Outcomes: 32 min durat...
# 8228  V2L-M2  PSM 10.1.2  <p></p><div><u>Learning Outcomes: 31 min durat...
# 8231  V2L-M2  PSM 10.1.3  <p></p><div><u>Learning Outcomes: 41 min durat...
# 8226  V2L-M2  PSM 10.1.4  <p></p><div><u>Learning Outcomes: 42 min durat...
# 8221  V2L-M2  PSM 10.2.1  <p></p><div><u>Learning Outcomes: 37 min durat...
# ...      ...         ...                                                ...
# 8168  V2L-M2   PSM 9.4.4  <p></p><div><u>Learning Outcomes: 31 min durat...
# 8170  V2L-M2   PSM 9.5.1  <p></p><div><u>Learning Outcomes: 50 min durat...
# 8172  V2L-M2   PSM 9.5.2  <p></p><div><u>Learning Outcomes: 49 min durat...
# 8195  V2L-M2   PSM 9.5.3  <p></p><div><u>Learning Outcomes: 50 min durat...
# 8197  V2L-M2   PSM 9.5.4  <p></p><div><u>Learning Outcomes: 40 min durat...
#
#                                            lo_formatted activity_formatted  \
# 7922  Learning Outcomes: 32 min duration.LO1:Describ...            U10S1T1
# 8228  Learning Outcomes: 31 min duration.LO1:Determi...            U10S1T2
# 8231  Learning Outcomes: 41 min duration.LO1:Determi...            U10S1T3
# 8226  Learning Outcomes: 42 min duration.LO1:Determi...            U10S1T4
# 8221  Learning Outcomes: 37 min duration.LO1: Determ...            U10S2T1
# ...                                                 ...                ...
# 8168  Learning Outcomes: 31 min duration.LO1:<span s...             U9S4T4
# 8170  Learning Outcomes: 50 min duration.LO1:Classif...             U9S5T1
# 8172  Learning Outcomes: 49 min duration.LO1: Determ...             U9S5T2
# 8195  Learning Outcomes: 50 min duration.LO1:<span s...             U9S5T3
# 8197  Learning Outcomes: 40 min duration.LO1:<span s...             U9S5T4
#
#                           lo_formatted_duration_removed duration activity_type
# 7922  O1:Describe\nPeriodic and\nOrthogonal Function...       32           PSM
# 8228    O1:Determine the Fourier Series of a Function         31           PSM
# 8231  O1:Determine\nthe Fourier Series of a\nDefined...       41           PSM
# 8226  O1:Determine the Fourier Series of an Even-Fun...       42           PSM
# 8221  O1: Determine Fourier Series of a Function hav...       37           PSM
# ...                                                 ...      ...           ...
# 8168  O1:<span style="font-size: 0.9375rem;">Apply t...       31           PSM
# 8170  O1:Classify Partial Differential EquationsLO2:...       50           PSM
# 8172     O1: Determine\nthe Solution of Wave\nEquation        49           PSM
# 8195  O1:<span style="font-size: 0.9375rem;">Determi...       50           PSM
# 8197  O1:<span style="font-size: 0.9375rem;">Determi...       40           PSM
#
# [229 rows x 8 columns]

# %%
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def helper(texts):
    b = list(texts).copy()
    b.sort(key=natural_keys)
    return b

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

subset_df.sort_values(by='activity_formatted_topic', key=helper)
# Out:
#        course                               activity  \
# 9820   V2L-NM                              PSM 3.1.2
# 9832   V2L-NM                              PSM 4.1.5
# 9822   V2L-NM                              PSM 3.2.1
# 9823   V2L-NM                              PSM 3.2.3
# 9824   V2L-NM                              PSM 3.2.4
# ...       ...                                    ...
# 9802  V2L-NAS                              PSM 7.4.1
# 9819   V2L-NM  ALM 3.2.1-1                      DBST
# 9817   V2L-NM         ALM 3.2.2-1               DBST
# 9816   V2L-NM                              PSM 3.1.1
# 9815   V2L-NM                              PSM 2.3.4
#
#                                          lo_unformatted  \
# 9820  <p></p><div><u></u></div><u>Problem&nbsp;<u st...
# 9832  <p></p><u>Problem&nbsp;<u style="font-size: 0....
# 9822  <p></p><div><u></u></div><u>Problem&nbsp;<u st...
# 9823  <p></p><div><u></u></div><div><u>Problem Learn...
# 9824  <span><u>Problem&nbsp;</u></span><u style="fon...
# ...                                                 ...
# 9802  <b><u>Problem Learning Outcomes: 50 min durati...
# 9819  <u>ALO 3.2.1-1: Classify the Partial Different...
# 9817  <u>ALO 3.2.2-1: Describe and apply the Finite ...
# 9816  <p></p><u>Problem&nbsp;<u style="font-size: 0....
# 9815  <p></p><div><u></u></div><u>Problem&nbsp;<u st...
#
#                                            lo_formatted activity_formatted  \
# 9820  Problem<u style="font-size: 0.9375rem;">Learni...             U3S1T2
# 9832  Problem<u style="font-size: 0.9375rem;">Learni...             U4S1T5
# 9822  Problem<u style="font-size: 0.9375rem;">Learni...             U3S2T1
# 9823  Problem Learning Outcomes: 38 min duration.PLO...             U3S2T3
# 9824  Problem<u style="font-size: 0.9375rem;">Learni...             U3S2T4
# ...                                                 ...                ...
# 9802  Problem Learning Outcomes: 50 min duration. PL...             U7S4T1
# 9819  ALO 3.2.1-1: Classify the Partial Differential...           U3S2T1-1
# 9817  ALO 3.2.2-1: Describe and apply the Finite Dif...           U3S2T2-1
# 9816  Problem<u style="font-size: 0.9375rem;">Learni...             U3S1T1
# 9815  Problem<u style="font-size: 0.9375rem;">Learni...             U2S3T4
#
#                           lo_formatted_duration_removed duration  \
# 9820  PLO1:Fit the given set of data in the Polynomi...       46
# 9832  <span style="font-size: 0.9375rem;">PLO1: Solv...       33
# 9822  PLO1: Discuss the Partial Differential Equatio...       37
# 9823  LO1: Solve Heat Equationusing Bender Schmidt M...       38
# 9824  PLO1: Solve Heat Equationusing Crank-Nicholson...       42
# ...                                                 ...      ...
# 9802  PLO1: Explain Hybrid and Inverse Hybrid parame...       50
# 9819  ALO 3.2.1-1: Classify the Partial Differential...        0
# 9817  ALO 3.2.2-1: Describe and apply the Finite Dif...        0
# 9816  PLO1: Apply the principle of Least Square in t...       47
# 9815  PLO1: Find the derivative from the set of data...        0
#
#      activity_type activity_formatted_topic
# 9820           PSM                   U3S1T2
# 9832           PSM                   U4S1T5
# 9822           PSM                   U3S2T1
# 9823           PSM                   U3S2T3
# 9824           PSM                   U3S2T4
# ...            ...                      ...
# 9802           PSM                   U7S4T1
# 9819           ALM                   U3S2T1
# 9817           ALM                   U3S2T2
# 9816           PSM                   U3S1T1
# 9815           PSM                   U2S3T4
#
# [9726 rows x 9 columns]

# %%
a = np.array(list(subset_df['activity_formatted_topic']).copy())
sorted(a, key=natural_keys)

[ c for c in re.split(r'(\d+)', 'U10S2T1') if c.isdigit()]
# Out:
# ['10', '2', '1']

# %%
ag =[[1,1], [1,1,1], [10,2,1], [2,1,2], [2,1]]
np.argsort(np.array(ag))
# Out:
# C:\Users\sanat\AppData\Local\Temp/ipykernel_15080/1780467726.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.argsort(np.array(ag))
# array([0, 1, 4, 3, 2], dtype=int64)

# %% [markdown]
# ### Remove duration

# %%
df.sort_values(by='sorting_col')
# Out:
#             course                                       activity  \
# 11048      V2L-SAS                                       GPSM 1.1
# 10677      V2L-RCC                                       GPSM 1.1
# 12592      V2L-TOM                                       GPSM 1.1
# 2638        V2L-CS                                       GPSM 1.1
# 12398      V2L-TOC                                       GPSM 1.1
# ...            ...                                            ...
# 3906   V2L-DigiElx                                      PSM 9.8.1
# 3490   V2L-DigiElx  ALM 9.8.1-                               DBET
# 1022   V2L-AnaCirc                                      VLM 9.8.1
# 1289   V2L-AnaCirc                                      PSM 9.8.1
# 1238   V2L-AnaCirc  ALM 9.8.1-1                              DBST
#
#                                           lo_unformatted  \
# 11048  <b><u>GATE Learning Outcomes: 11 min duration....
# 10677  <b><u>GATE Learning Outcomes: 20 min duration....
# 12592  <b><u>GATE Learning Outcomes: 18 min duration....
# 2638   <b><u>GATE Learning Outcomes: 31 min duration....
# 12398  <b><u>GATE Learning Outcomes: 31 min duration....
# ...                                                  ...
# 3906   <p></p><b><u>Problem&nbsp;<b style="font-size:...
# 3490   <p>Describe&nbsp;<span>Sample and Hold Circuit...
# 1022   <p></p><p><b><u><span lang="EN-IN"></span></u>...
# 1289   <u><b>Problem Learning Outcomes: 7 min duratio...
# 1238   <u><b>Active Learning Outcomes: 12 min duratio...
#
#                                             lo_formatted activity_formatted  \
# 11048  GATE Learning Outcomes: 11 min duration. GLO1:...               U1S1
# 10677  GATE Learning Outcomes: 20 min duration. GLO1:...               U1S1
# 12592  GATE Learning Outcomes: 18 min duration. GLO1:...               U1S1
# 2638   GATE Learning Outcomes: 31 min duration. GLO1:...               U1S1
# 12398  GATE Learning Outcomes: 31 min duration. GLO1:...               U1S1
# ...                                                  ...                ...
# 3906   Problem<b style="font-size: 0.9375rem;">Learni...             U9S8T1
# 3490   DescribeSample and Hold Circuit using Op-Amp: ...            U9S8T1-
# 1022   <span lang="EN-IN"><span lang="EN-IN"><span la...             U9S8T1
# 1289   Problem Learning Outcomes: 7 min duration. PLO...             U9S8T1
# 1238   Active Learning Outcomes: 12 min duration. ALO...           U9S8T1-1
#
#                            lo_formatted_duration_removed duration  \
# 11048  GLO1: Apply properties of Impulse Function GLO...       11
# 10677  GLO1: Analyze the relation between Characteris...       20
# 12592  GLO1: Solve the problems related to the follow...       18
# 2638   GLO1: Determine a true statement for the Negat...       31
# 12398  GLO1:  Solve GATE questions based on the conce...       31
# ...                                                  ...      ...
# 3906   PLO1: Design the circuit of<span style="font-s...        7
# 3490   DescribeSample and Hold Circuit using Op-Amp: ...        0
# 1022   CLO1:<span style="font-size: 0.9375rem;">Descr...        0
# 1289   PLO1: Design the circuit of Sample and Hold ci...        7
# 1238   ALO 9.8.1-1: Describe Sample and Hold Circuit ...       12
#
#       activity_type activity_formatted_topic   sorting_col
# 11048          GPSM                     U1S1        (1, 1)
# 10677          GPSM                     U1S1        (1, 1)
# 12592          GPSM                     U1S1        (1, 1)
# 2638           GPSM                     U1S1        (1, 1)
# 12398          GPSM                     U1S1        (1, 1)
# ...             ...                      ...           ...
# 3906            PSM                   U9S8T1     (9, 8, 1)
# 3490            ALM                   U9S8T1     (9, 8, 1)
# 1022           None                   U9S8T1     (9, 8, 1)
# 1289            PSM                   U9S8T1     (9, 8, 1)
# 1238            ALM                   U9S8T1  (9, 8, 1, 1)
#
# [12950 rows x 10 columns]

# %%
df
# Out:
#            course                                           activity  \
# 0        V2L-ADCS           ALM 4.2.4-2                         DBST
# 1        V2L-ADCS          ALM 2.3.3-2                          DBST
# 2        V2L-ADCS      ALM 2.3.3-1                              DBST
# 3        V2L-ADCS         ALM 2.2.4-1                           DBST
# 4        V2L-ADCS               ALM 1.4.5-2                     DBST
# ...           ...                                                ...
# 12945  V2L-Thermo  ALM 5.1.2-3                                   ...
# 12946  V2L-Thermo  ALM 5.1.1-4                                   ...
# 12947  V2L-Thermo    ALM 5.1.1-1                                DBST
# 12948  V2L-Thermo  ALM 6.1.1-2                                   ...
# 12949  V2L-Thermo  ALM 2.1.3-2                                   ...
#
#                                           lo_unformatted  \
# 0      <b><u>Active Learning Outcomes: 32 min duratio...
# 1      <b><u>Active Learning Outcomes: 6 min duration...
# 2      <b><u>Active Learning Outcomes: 6 min duration...
# 3      <b><u>Active Learning Outcomes: 21 min duratio...
# 4      <b><u>Active Learning Outcomes: 15 min duratio...
# ...                                                  ...
# 12945  <b><u>Active Learning Outcomes: 23 min duratio...
# 12946  <b><u>Active Learning Outcomes: 13 min duratio...
# 12947  <b><u>Active Learning Outcomes: 23 min duratio...
# 12948  <b><u>Active Learning Outcomes: 20 min duratio...
# 12949  <b><u>Active Learning Outcomes: 39 min duratio...
#
#                                             lo_formatted activity_formatted  \
# 0      Active Learning Outcomes: 32 min duration. ALO...           U4S2T4-2
# 1      Active Learning Outcomes: 6 min duration. ALO ...           U2S3T3-2
# 2      Active Learning Outcomes: 6 min duration. ALO ...           U2S3T3-1
# 3      Active Learning Outcomes: 21 min duration. ALO...           U2S2T4-1
# 4      Active Learning Outcomes: 15 min duration. ALO...           U1S4T5-2
# ...                                                  ...                ...
# 12945  Active Learning Outcomes: 23 min duration. ALO...           U5S1T2-3
# 12946  Active Learning Outcomes: 13 min duration. ALO...           U5S1T1-4
# 12947  Active Learning Outcomes: 23 min duration. ALO...           U5S1T1-1
# 12948  Active Learning Outcomes: 20 min duration. ALO...           U6S1T1-2
# 12949  Active Learning Outcomes: 39 min duration. ALO...           U2S1T3-2
#
#                            lo_formatted_duration_removed duration  \
# 0      ALO 4.2.4-2: Recall SNR at the Output of the F...       32
# 1      ALO 2.3.3-2: Show the Phasor Representation of...        6
# 2      ALO 2.3.3-1: Show the Phasor Representation of...        6
# 3      ALO 2.2.4-1: Describe Demodulation of FM Signa...       21
# 4                ALO 1.4.5-2: Compare various AM Systems       15
# ...                                                  ...      ...
# 12945  ALO 5.1.2-3: Recall the concept of Triple Poin...       23
# 12946  ALO 5.1.1-4: Derive the expression for various...       13
# 12947  ALO 5.1.1-1: Recall the concept of Phase chang...       23
# 12948  ALO 6.1.1-2: Recall the following Laws:\n i. D...       20
# 12949  ALO 2.1.3-2: Derive the Steady Flow Energy Equ...       39
#
#       activity_type activity_formatted_topic   sorting_col
# 0               ALM                   U4S2T4  (4, 2, 4, 2)
# 1               ALM                   U2S3T3  (2, 3, 3, 2)
# 2               ALM                   U2S3T3  (2, 3, 3, 1)
# 3               ALM                   U2S2T4  (2, 2, 4, 1)
# 4               ALM                   U1S4T5  (1, 4, 5, 2)
# ...             ...                      ...           ...
# 12945           ALM                   U5S1T2  (5, 1, 2, 3)
# 12946           ALM                   U5S1T1  (5, 1, 1, 4)
# 12947           ALM                   U5S1T1  (5, 1, 1, 1)
# 12948           ALM                   U6S1T1  (6, 1, 1, 2)
# 12949           ALM                   U2S1T3  (2, 1, 3, 2)
#
# [12950 rows x 10 columns]
