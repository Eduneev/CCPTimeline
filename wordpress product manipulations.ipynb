# %%
import pandas as pd
import math

# %%
csv = "wc-product-export-23-3-2021.csv"

# %%
df = pd.read_csv(csv, encoding = "utf-8")

# %%
df.keys()
# Out:
# Index(['ID', 'Type', 'SKU', 'Name', 'Published', 'Is featured?',
#        'Visibility in catalog', 'Short description', 'Description',
#        'Date sale price starts', 'Date sale price ends', 'Tax status',
#        'Tax class', 'In stock?', 'Stock', 'Low stock amount',
#        'Backorders allowed?', 'Sold individually?', 'Weight (kg)',
#        'Length (cm)', 'Width (cm)', 'Height (cm)', 'Allow customer reviews?',
#        'Purchase note', 'Sale price', 'Regular price', 'Categories', 'Tags',
#        'Shipping class', 'Images', 'Download limit', 'Download expiry days',
#        'Parent', 'Grouped products', 'Upsells', 'Cross-sells', 'External URL',
#        'Button text', 'Position', 'WCPA Forms', 'Attribute 1 name',
#        'Attribute 1 value(s)', 'Attribute 1 visible', 'Attribute 1 global',
#        'Meta: _nickx_video_text_url', 'Meta: slide_template',
#        'Meta: rs_page_bg_color', 'Meta: is_product_a_moodle_course',
# ...

# %%
q1=df[df['Position']==4]
q2=df[df['Position']==3]
df.iloc[0]['Position']
# Out:
# 0

# %%
len(q1)

last_idx = 0
last_row = None
for idx, row in enumerate(df.iterrows()):
    row = row[1]
    if row['Position']==1 and idx!=0:
        if df.iloc[idx-1]
# Out:
#   File "<ipython-input-109-c759bee1dcad>", line 4
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
df
df.loc[df['Position']==0, 'Parent']=''
df.to_csv('wc-product-export3.csv')

# %%
a = df[df['Position']<5]

# %%
a.keys()
a
# Out:
#          ID       Type  SKU                                     Name  \
# 0     16663   variable  NaN                   AKTU - Data Structures
# 1     16664  variation  NaN       AKTU - Data Structures - 5, KCS301
# 2     16665  variation  NaN      AKTU - Data Structures - 30, KCS301
# 3     16666  variation  NaN      AKTU - Data Structures - 50, KCS301
# 4     16667  variation  NaN       AKTU - Data Structures - 5, RCS305
# ...     ...        ...  ...                                      ...
# 2284  19723   variable  NaN                RTU - Digital Electronics
# 2285  19724  variation  NaN   RTU - Digital Electronics - 5, 3IT3-04
# 2286  19725  variation  NaN  RTU - Digital Electronics - 30, 3IT3-04
# 2287  19726  variation  NaN  RTU - Digital Electronics - 50, 3IT3-04
# 2288  19727  variation  NaN   RTU - Digital Electronics - 5, 4EE4-08
#
#       Published  Is featured? Visibility in catalog Short description  \
# ...

# %%
a['Name'] = a.Name.apply(lambda s: s.split(",")[0])
# Out:
# C:\Users\sanat\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
a['Attribute 1 value(s)'] = a['Attribute 1 value(s)'].apply(lambda x: x + ", 1" if ',' in x else x)
# Out:
# C:\Users\sanat\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
a.loc[a['Position']==4, 'Attribute 1 value(s)'] = 1
# Out:
# C:\Users\sanat\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
a.loc[a['Position']==4, 'Regular price'] = 100
# Out:
# C:\Users\sanat\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
for idx, i in enumerate(a.iterrows()):

    row = i[1]
    if row['Position'] == 4:
        d = row['Name'][:-1]
        a.iloc[idx,3] = d + '1'
# Out:
# C:\Users\sanat\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
a.to_csv("wc-product-export.csv")

# %%
# Out:
# '34'
